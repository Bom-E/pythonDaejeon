# %% [markdown]
# # 데이터 프레임화 작업

# %%
# pandas 라이브러리 사용
import pandas as pd

# api 데이터 추출
import requests

# api 보안
import os

# .env
from dotenv import load_dotenv

# %%
# 요일

df_day = pd.read_csv('data/경찰청 대전광역시경찰청_대전지역 요일별 범죄발생현황_20221231.csv', encoding='CP949')

df_day.set_index('연도', inplace=True)

df_day.index = df_day.index.astype(str)

df_del = df_day[df_day.index.str.contains('2017|2018')]

df_day = df_day.drop(df_del.index)

df_day
# Out:
#          항목     일     월     화     수     목     금     토
# 연도
# 2019    강력범   116   103   122    91    99   125   150
# 2019    절도범   770   882   743   804   835   918   903
# 2019    폭력범  1221  1086  1131  1075  1076  1251  1367
# 2019    지능범   894  1832  1835  1839  1818  1815   908
# 2019    풍속범    19    29    21    24    25    31    20
# 2019  기타형법범   312   430   391   419   471   428   339
# 2019   특별법범  1819  2522  2458  2401  2423  2630  2146
# 2020    강력범   110    94    93   103    98   119   114
# 2020    절도범   701   725   714   720   729   826   842
# 2020    폭력범  1246  1078  1124  1141  1112  1232  1330
# 2020    지능범   905  2172  2171  2037  1933  2024  1055
# 2020    풍속범    25    38    25    23    30    31    14
# 2020  기타형법범   295   449   455   449   445   412   363
# 2020   특별법범  1667  2266  2206  2134  2362  2406  1977
# 2021    강력범    89   107   106    90   100    93   131
# 2021    절도범   654   748   737   711   718   745   731
# ...

# %%
# 시간

df_time = pd.read_csv('data/경찰청 대전광역시경찰청_대전지역 시간대별 범죄 발생 현황_20221231.csv', encoding='CP949')

df_time.set_index('연도', inplace=True)

df_time.index = df_time.index.astype(str)

df_del = df_time[df_time.index.str.contains('2017|2018')]

df_time = df_time.drop(df_del.index)

df_time
# Out:
#          항목  심     야(0시-4시)  새     벽(4시-7시)  오     전(7시-12시)  \
# 연도
# 2019    강력범             317              80               76
# 2019    절도범            1169             402              972
# 2019    폭력범            2438             576              982
# 2019    지능범            6869             135             1244
# 2019    풍속범              47               9               22
# 2019  기타형법범            1327              71              337
# 2019   특별법범            3866             751             2630
# 2020    강력범             271              75               64
# 2020    절도범            1088             399              853
# 2020    폭력범            2366             577              933
# 2020    지능범            7671             123             1297
# 2020    풍속범              50               5               16
# 2020  기타형법범            1263             112              361
# 2020   특별법범            3697             694             2342
# ...

# %%
# 5대 범죄
# 추후 시각화 작업을 위해 인덱스명 통일

df_five = pd.read_csv('data/경찰청 대전광역시경찰청_연도 및 자치구별 5대 범죄 발생 현황_20221231.csv', encoding="CP949")

df_five.rename(columns={'연도별':'연도'}, inplace=True)

df_five['연도'] = df_five['연도'].str.replace('년', "")

df_five.set_index('연도', inplace=True)

df_five
# Out:
#           관서명    구분     계  살인  강도  강간강제추행    절도    폭력
# 연도
# 2019  대전중부경찰서  발생건수  2927   5   6     141  1221  1554
# 2019  대전중부경찰서  검거건수  2254   5   6     118   677  1448
# 2019  대전동부경찰서  발생건수  2516   3   8      83  1176  1246
# 2019  대전동부경찰서  검거건수  1999   3   8      74   796  1118
# 2019  대전서부경찰서  발생건수  2393   1   4     104   815  1469
# 2019  대전서부경찰서  검거건수  1909   1   4      93   512  1299
# 2019  대전대덕경찰서  발생건수  1822   0   1      60   646  1115
# 2019  대전대덕경찰서  검거건수  1486   0   1      44   435  1006
# 2019  대전둔산경찰서  발생건수  2649   3   4     188   974  1480
# 2019  대전둔산경찰서  검거건수  1964   2   4     154   514  1290
# 2019  대전유성경찰서  발생건수  2514   6   2     137  1024  1345
# 2019  대전유성경찰서  검거건수  2277   6   1     123   906  1241
# 2020  대전중부경찰서  발생건수  2765   2   3     127  1028  1605
# 2020  대전중부경찰서  검거건수  2311   2   3     110   696  1500
# 2020  대전동부경찰서  발생건수  2486   1   4      91  1035  1355
# 2020  대전동부경찰서  검거건수  1904   1   5      73   659  1166
# ...

# %%
load_dotenv()

url = 'http://apis.data.go.kr/6300000/openapi2022/safeCCTV/getsafeCCTV'
params = {
    'serviceKey' : os.getenv('my_service_key')
    , 'numOfRows' : '2985'
    , 'pageNo' : '1'
}

# .env 적용 드디어 해결! 이거 해결 하지 전에는 안 자려고 했는데 이제 잔다!

response = requests.get(url, params=params)

result_data = response.json()

# print(result_data)

items = result_data['response']['body']['items']

# for item in items:
    # print(f"관리번호 : {item['manageNo']}, 주소 : {item['lnmAdres']}, x좌표 : {item['crdntX']}, y좌표 : {item['crdntY']}")

# 글 길이가 제멋대로라서 간단한 replace로 불가능.(가능 할 것 같은데, 우악스러워질듯) 
# 데이터의 구성을 보니
# 1. . 을 기준으로 no를 부여
# 2. 처음 나오는 ()로 cctv 관할구와 숫자범위를 부여
# 3. 지도상 주소명

# 따라서 )를 기준으로 나누기.

# 데이터의 구조 : 'manageNo': '091.(서대전 88-2)동성이용원(서대전초교 뒷길)(회전)'
# 구현 이유 : 사용자가 이해할 만한 cctv의 자연어 명칭 뽑아내기

def adres_name(manage_no):
    # ')' 기준 분할 (cctv 명칭 데이터)
    adres_name = manage_no.split(')', 1)
    return adres_name[1] if len(adres_name) > 1 else manage_no.split('.', 1)[1]

def transform_item(item):
    return{
        'manageNo' : item['manageNo'][0:3]
        , 'address_name' : adres_name(item['manageNo'])
        , 'address' : item['lnmAdres']
        , 'x' : item['crdntX']
        , 'y' : item['crdntY']
    }

cctv_list = list(map(transform_item, items))

# 리스트를 데이터프레임으로 바꾸기
df_cctv = pd.DataFrame(cctv_list)

df_cctv.set_index("manageNo", inplace=True)

df_cctv
# Out:
#              address_name        address             x            y
# manageNo
# 041              말바위어린이공원  유성구 신성동 150-1  127.33880587  36.40702848
# 047          산수어린이공원(공원내)    유성구 전민동 265  127.39566765  36.40030933
# 048        어은어린이공원(공원앞4가)    유성구 어은동 108  127.35567331  36.36264646
# 051               윳골어린이공원   유성구 궁동 414-8  127.34855126  36.36261575
# 052               봉암어린이공원   유성구 궁동 430-1  127.35178965  36.36146350
# ...                   ...            ...           ...          ...
# 112       대덕오월드 102동앞(회전)   중구 산성동 275-5  127.38797990  36.30219280
# 113       대덕오월드 102동앞(고정)   중구 산성동 275-5  127.38797990  36.30219280
# 114        탑전기 앞 철길방향(회전)   중구 산성동 168-5  127.38653880  36.30783480
# 115        탑전기 앞 철길방향(고정)   중구 산성동 168-5  127.38653880  36.30783480
# 116        사천성 맞은편 천변(회전)  중구 산성동 166-22  127.38606110  36.30925430
#
# [2985 rows x 4 columns]

# %%
df_dict1 = pd.read_csv('data/대전광역시_유성구_여성안심지킴이집_20240214.csv', encoding="CP949")
df_dict2 = pd.read_csv('data/대전광역시_중구_여성안심지킴이집_20231130.csv', encoding="CP949")
df_dict3 = pd.read_csv('data/대전광역시_서구_여성안심지킴이집_20231109.csv', encoding="CP949")
df_dict4 = pd.read_csv('data/대전광역시_동구_여성안심지킴이집_20230721.csv', encoding="CP949")
df_dict5 = pd.read_csv('data/대전광역시_대덕구_여성안심지킴이집_20230419.csv', encoding="CP949")

df_house = [df_dict1, df_dict2, df_dict3, df_dict4, df_dict5]

for i in range(len(df_house)):
    df_house[i].columns = df_house[i].columns.str.strip()
    df_house[i] = df_house[i][df_house[i]['운영여부'] != 'N']

df_result = pd.concat(df_house, ignore_index=True)

# 지정연도, 운영여부 삭제(운영여부는 어차피 전부 Y임)
df_result = df_result.drop(columns=['지정연도', '운영여부'])

df_result

# 데이터 결측치 제거(원래 NaN 데이터를 날리려 했으나, 데이터 조회 후 결정.)
# df_result[df_result.isna().any(axis=1)]

# NaN 데이터가 있는 행만 조회
df_result[df_result.isna().any(axis=1)]

# 폐업신고 한 가게 행 삭제
drop_data = [22, 61, 74, 118, 126, 140, 153, 154, 158]
df_result.drop(drop_data, axis=0, inplace=True)

# 전화번호 NaN 수정
# iat으로 하니까 기존 데이터의 인덱스에 데이터가 덧씌워진다...
# 레이어 기준이 아니라 위치 기준이라서 그럴 가능성이 큰 듯. 게다가 행 삭제 하고 인덱스 재지정도 안 해줬으니...
# 폐업 파악 후 인덱스 재지정 해주자. (그러고 iat으로 잘못 지정한 전화번호 값 2개도 수정해야함...)
df_result.at[31, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[32, '여성안심지킴이집전화번호'] = '전화번호 없음 (이마트24 소비자보호센터: 02-6916-1500)'
df_result.at[33, '여성안심지킴이집전화번호'] = '070-7740-0008'
df_result.at[34, '여성안심지킴이집전화번호'] = '전화번호 없음'
df_result.at[40, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[42, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[48, '여성안심지킴이집전화번호'] = '042-522-7433'
df_result.at[51, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[52, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[53, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[71, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[75, '여성안심지킴이집전화번호'] = '080-999-5425'
df_result.at[81, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[119, '여성안심지킴이집전화번호'] = '0507-1320-1326'
df_result.at[120, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[121, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[122, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[123, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[124, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[125, '여성안심지킴이집전화번호'] = '전화번호 없음 (CU 소비자보호센터: 1577-8007)'
df_result.at[127, '여성안심지킴이집전화번호'] = '전화번호 없음'
df_result.at[128, '여성안심지킴이집전화번호'] = '042-271-8401'
df_result.at[129, '여성안심지킴이집전화번호'] = '080-999-5425'
df_result.at[130, '여성안심지킴이집전화번호'] = '042-622-0464'
df_result.at[131, '여성안심지킴이집전화번호'] = '042-631-7005'
df_result.at[132, '여성안심지킴이집전화번호'] = '전화번호 없음 (GS 소비자보호센터: 080-999-5425)'
df_result.at[133, '여성안심지킴이집전화번호'] = '042-533-6410'
df_result.at[134, '여성안심지킴이집전화번호'] = '전화번호 없음 (GS 소비자보호센터: 080-999-5425)'
df_result.at[135, '여성안심지킴이집전화번호'] = '042-242-5644'
df_result.at[136, '여성안심지킴이집전화번호'] = '전화번호 없음 (GS 소비자보호센터: 080-999-5425)'
df_result.at[137, '여성안심지킴이집전화번호'] = '042-242-5644'
df_result.at[138, '여성안심지킴이집전화번호'] = '전화번호 없음 (GS 소비자보호센터: 080-999-5425)'
df_result.at[139, '여성안심지킴이집전화번호'] = '042-271-8402'
df_result.at[141, '여성안심지킴이집전화번호'] = '042-242-5644'
df_result.at[142, '여성안심지킴이집전화번호'] = '042-242-5644'
df_result.at[143, '여성안심지킴이집전화번호'] = '042-621-0888'
df_result.at[144, '여성안심지킴이집전화번호'] = '전화번호 없음 (세븐일레븐 소비자보호센터: 1577-0711)'
df_result.at[145, '여성안심지킴이집전화번호'] = '전화번호 없음 (이마트24 소비자보호센터: 02-6916-1500)'
df_result.at[146, '여성안심지킴이집전화번호'] = '042-931-5155'
df_result.at[147, '여성안심지킴이집전화번호'] = '042-621-3213'
df_result.at[148, '여성안심지킴이집전화번호'] = '070-8823-7612'
df_result.at[149, '여성안심지킴이집전화번호'] = '042-626-6711'
df_result.at[150, '여성안심지킴이집전화번호'] = '042-625-7110'
df_result.at[151, '여성안심지킴이집전화번호'] = '042-627-1668'
df_result.at[152, '여성안심지킴이집전화번호'] = '042-343-8356'
df_result.at[155, '여성안심지킴이집전화번호'] = '042-933-8085'
df_result.at[156, '여성안심지킴이집전화번호'] = '042-635-3168'
df_result.at[157, '여성안심지킴이집전화번호'] = '042-622-2020'
df_result.at[159, '여성안심지킴이집전화번호'] = '전화번호 없음 (세븐일레븐 소비자보호센터: 1577-0711)'


# 카카오주소 api를 통해 지번주소가 NaN 제거


# 주소 NaN 수정
# 아름답지 않아... 카카오주소api를 이용해서 자동화 하면 될 것 같은데... 일단 생각해보자
# 1. 카카오주소 api를  requests로 불러오기
# 2. if문으로 소재지지번주소가 NaN 값인 행들을 조회
# 3. 소재지도로명주소를 잘라서 검색 후 지번주소를 찾아서 넣기.

# 좀 더 적합한 api를 찾음 (주소기반산업지원서비스)

load_dotenv()

def get_jibun(road_address):
    url = "https://business.juso.go.kr/addrlink/addrLinkApi.do"
    params = {
        "confmKey": os.getenv('address_key'),
        "currentPage": "1",
        "countPerPage": "10",
        "keyword": road_address,
        "resultType": "json"
    }

    response = requests.get(url, params=params)
    data = response.json()

    if data['results']['common']['totalCount'] != '0':
        # null 처리
        return data['results']['juso'][0]['jibunAddr']
    else:
        return "주소를 찾을 수 없습니다."

# 데이터 확인
# road_address = "울산광역시 울주군 삼남읍 도호 1길 39-11"
# jibun_address = get_jibun(road_address)
# print(f"도로명주소: {road_address}")
# print(f"지번주소: {jibun_address}")

# 기존 데이터프레임에 소재지지번주소 데이터 추가

copy_df = df_result.copy()

mask = copy_df['소재지지번주소'].isna()

copy_df.loc[mask, '임시_소재지지번주소'] = copy_df.loc[mask, '소재지도로명주소'].apply(get_jibun)

df_result.loc[mask, '소재지지번주소'] = copy_df.loc[mask, '임시_소재지지번주소']

# print(df_result['소재지지번주소'])

del copy_df

# 전화번호가 없는 지점(결측치 처리 후 마지막에 할 것.)
# df_result['여성안심지킴이집전화번호'].fillna('전화번호 없음', inplace=True)

# 인덱스 재지정(이것도 결측치 처리 후 마지막에 할 것.)
# df_result.reset_index(drop=True, inplace=True)

df_result[df_result.isna().any(axis=1)]

df_result[df_result['소재지지번주소'] == '주소를 찾을 수 없습니다.']

# 1. 주소를 찾을 수 없습니다. 주소 찾아서 넣기, 안 된 이유가 뭔지 분석하기
# CU월평사랑점 : 도로명 주소에 건물 번호와 건물 명이 함께 붙어있음(정작 도로명 주소를 검색하면 건물 명은 안 뜸)
# GS월평타운점 : 도로명 주소에 건물 번호와 . + 층명 함께 붙어있음(정작 도로명 주소를 검색하면 번호는 안 뜸)
# 아마트24 월평중앙점 : 위와 이하동문

# 데이터 재가공
df_result.at[81, '소재지도로명주소'] = '대전 서구 월평북로 27 (월평동) 1층 101호'
df_result.at[81, '소재지지번주소'] = '대전광역시 서구 월평동 218-6'
df_result.at[82, '소재지도로명주소'] = '대전광역시 서구 월평서로6번길 26'
df_result.at[82, '소재지지번주소'] = '대전광역시 서구 월평동 1069'
df_result.at[83, '소재지도로명주소'] = '대전광역시 서구 계룡로231번길 9'
df_result.at[83, '소재지지번주소'] = '대전광역시 서구 월평동 1407'

df_result.at[131, '점포명'] = 'GS25시 대전법동점'
df_result.at[141, '점포명'] = '이마트24 대전비래점'
df_result.at[143, '점포명'] = 'JH24 편의점(재천사마트24시편의점)'
df_result.at[144, '점포명'] = '세븐일레븐 대전오정동아점'
df_result.at[145, '점포명'] = '이마트24 대전신탄IC점'
df_result.at[152, '점포명'] = '세븐일레븐 대전법동영진점(법 1동)'
df_result.at[155, '점포명'] = '세븐일레븐 신탄공단점'
df_result.at[156, '점포명'] = '순우리뼈감자탕'
df_result.at[157, '점포명'] = '씨티할인마트정육'

# 데이터 확인
df_result[df_result['점포명'] == 'CU 월평사랑점']
# Out:
# Empty DataFrame
# Columns: [점포명, 시도명, 시군구명, 시군구코드, 소재지도로명주소, 소재지지번주소, 위도, 경도, 여성안심지킴이집전화번호, 관할경찰서명, 데이터기준일자]
# Index: []

# %%
# 밤길 치안 api에서 대전지역만 뽑아내서 데이터 받기

# %% [markdown]
# # maria db 연결

# %%
import pymysql

# %%
def getConnection():
    conn = pymysql.connect(
        host='localhost'
        , user='study_user'
        , password='mariadb'
        , db='study_db'
        , charset='utf8')
    return conn
